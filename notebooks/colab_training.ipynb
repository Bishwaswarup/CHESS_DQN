# %% [markdown]
# # Chess DQN training
# Upload or clone this repository, install its requirements, then run the training script.

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --episodes 1000
